# %%
# import pandas
import pandas as pd
import numpy as np

# %%
# Optional: use the pd.set_option() to display all rows in a dataframe by default
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# # Create a DataFrame

# %%
# read the "bestsellers with categories" csv file (Dataset on Amazon's Top 50 bestselling books from 2009 to 2019.)
df = pd.read_csv('bestsellers_with_categories.csv')
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# get access to the shape attribute
df.shape
# Out:
# (550, 7)

# %%
# find the data types of each column
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Disaplying a DataFrame

# %%
# show first 5 rows in a dataframe
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# describe basic statistics of the dataframe (mean, std, min, max)
df.describe().round(2)
# Out:
#        User Rating   Reviews   Price     Year
# count       550.00    550.00  550.00   550.00
# mean          4.62  11953.28   13.10  2014.00
# std           0.23  11731.13   10.84     3.17
# min           3.30     37.00    0.00  2009.00
# 25%           4.50   4058.00    7.00  2011.00
# 50%           4.70   8580.00   11.00  2014.00
# 75%           4.80  17253.25   16.00  2017.00
# max           4.90  87841.00  105.00  2019.00

# %% [markdown]
# # Add a new Column with an array

# %%
# Your task is to create a column named 'Critic Rating' that should have random integer numbers between 1 and 4

# 1. import numpy and create 550 random integer numbers between 1 and 4

# 2. add new 'Critic Rating' column to dataframe using the random numbers created


# Note the random numbers in this new 'Critic Rating' column will be different between your solution and mine, but we'll focus only on the code, in this section.
num_rand = np.random.randint(1, 5, size=550)
df['Critic Rating'] = num_rand

# %%
# show first 5 rows
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              4
# 1              4
# 2              1
# 3              3
# 4              3

# %% [markdown]
# # Basic Attributes, Methods and Functions

# %%
# get access to the columns attribute
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic Rating'],
#       dtype='object')

# %% [markdown]
# # Selecting Two or More Columns from a Dataframe

# %%
# move the new 'Critic Rating' column between the columns "User Rating" and "Reviews" Then update the dataframe

# Tip: Copy and paste the column names obtained with the columns attribute and then rearrange elements using [[]]
new_df = df[['User Rating', 'Critic Rating', 'Reviews']]

# %%
df_new = df.copy()
df_new.drop('Critic Rating', axis=1, inplace=True)
df_new.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
#df_new.insert(3, 'Critic Rating', num_rand)
df_new.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Critic Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              4    17350      8  2016
# 1              Stephen King          4.6              4     2052     22  2011
# 2        Jordan B. Peterson          4.7              1    18979     15  2018
# 3             George Orwell          4.7              3    21424      6  2017
# 4  National Geographic Kids          4.8              3     7665     12  2019
#
#          Genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction
# 4  Non Fiction

# %%
# show first 5 rows
new_df.head()
# Out:
#    User Rating  Critic Rating  Reviews
# 0          4.7              4    17350
# 1          4.6              4     2052
# 2          4.7              1    18979
# 3          4.7              3    21424
# 4          4.8              3     7665

# %% [markdown]
# # Operations on Dataframes

# %%
# create a column named "Average Rating" by using the following formula: Average Rating = (User Rating + Critic Rating)/2
df['Average Rating'] = (df['User Rating'] + df['Critic Rating'])/2

# %%
# use the round function to round the values of the dataframe to 1 decimal and update the dataframe
df = df.round(1)
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating  Average Rating
# 0              4             4.4
# 1              4             4.3
# 2              1             2.8
# 3              3             3.8
# 4              3             3.9

# %% [markdown]
# # Value Counts

# %%
# count elements in "Genre" column by category and return the relative frequency 
df['Genre'].value_counts(normalize=True)
# Out:
# Genre
# Non Fiction    0.563636
# Fiction        0.436364
# Name: proportion, dtype: float64

# %% [markdown]
# # Rename Columns

# %%
# rename columns "User Rating," "Critic Rating" and "Average Rating" to "UR," "CR" and "AR" then update the dataframe with the inplace paraneter
df.rename(columns = {'User Rating': 'UR', 'Critic Rating': 'CR', 'Average Rating': 'AR'}, inplace=True)

# %%
# show first 5 rows
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  Reviews  Price  Year        Genre  CR   AR
# 0                  JJ Smith  4.7    17350      8  2016  Non Fiction   4  4.4
# 1              Stephen King  4.6     2052     22  2011      Fiction   4  4.3
# 2        Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   1  2.8
# 3             George Orwell  4.7    21424      6  2017      Fiction   3  3.8
# 4  National Geographic Kids  4.8     7665     12  2019  Non Fiction   3  3.9

# %%
# select only "Name", "Author", "UR", "CR", "AR" and "Year" columns and update dataframe
df = df[['Name', 'Author', 'UR', 'CR', 'AR', 'Year']]
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  CR   AR  Year
# 0                  JJ Smith  4.7   4  4.4  2016
# 1              Stephen King  4.6   4  4.3  2011
# 2        Jordan B. Peterson  4.7   1  2.8  2018
# 3             George Orwell  4.7   3  3.8  2017
# 4  National Geographic Kids  4.8   3  3.9  2019

# %% [markdown]
# # Sort a dataframe

# %%
# sort the dataframe descending by "UR" and "CR"
df.sort_values(by=['UR', 'CR'], ascending=False).head()
# Out:
#                                                   Name           Author   UR  \
# 40            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.  4.9
# 41            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.  4.9
# 82   Dog Man: A Tale of Two Kitties: From the Creat...       Dav Pilkey  4.9
# 85   Dog Man: Fetch-22: From the Creator of Captain...       Dav Pilkey  4.9
# 153  Harry Potter and the Chamber of Secrets: The I...     J.K. Rowling  4.9
#
#      CR   AR  Year
# 40    4  4.4  2017
# 41    4  4.4  2019
# 82    4  4.4  2017
# 85    4  4.4  2019
# 153   4  4.4  2016
